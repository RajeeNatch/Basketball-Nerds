# %%
import requests
import pandas as pd 
import json
import numpy as py 
from flask import Flask, render_template, redirect
from splinter import Browser
from bs4 import BeautifulSoup as bs
from flask_pymongo import PyMongo
from webdriver_manager.chrome import ChromeDriverManager
from sqlalchemy import create_engine,inspect
import sqlite3
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from config import API_KEY

# %%
url = "https://free-nba.p.rapidapi.com/players"

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': API_KEY
    }

response = requests.request("GET", url, headers=headers, params=querystring)

# print(response.text)
player_api = response.text
player_api
player_data = json.loads(player_api)
player_data
# Out:
# {'data': [{'id': 14,
#    'first_name': 'Ike',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Anigbogu',
#    'position': 'C',
#    'team': {'id': 12,
#     'abbreviation': 'IND',
#     'city': 'Indiana',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Indiana Pacers',
#     'name': 'Pacers'},
#    'weight_pounds': None},
#   {'id': 25,
#    'first_name': 'Ron',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Baker',
#    'position': 'G',
#    'team': {'id': 20,
#     'abbreviation': 'NYK',
#     'city': 'New York',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'New York Knicks',
#     'name': 'Knicks'},
#    'weight_pounds': None},
#   {'id': 47,
#    'first_name': 'Jabari',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Bird',
#    'position': 'G',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'weight_pounds': None},
#   {'id': 67,
#    'first_name': 'MarShon',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Brooks',
#    'position': 'G',
#    'team': {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    'weight_pounds': None},
#   {'id': 71,
#    'first_name': 'Lorenzo',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Brown',
#    'position': 'G',
#    'team': {'id': 28,
#     'abbreviation': 'TOR',
#     'city': 'Toronto',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Toronto Raptors',
#     'name': 'Raptors'},
#    'weight_pounds': None},
#   {'id': 90,
#    'first_name': 'Omri',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Casspi',
#    'position': 'F',
#    'team': {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    'weight_pounds': None},
#   {'id': 1,
#    'first_name': 'Alex',
#    'height_feet': 6,
#    'height_inches': 6,
#    'last_name': 'Abrines',
#    'position': 'G',
#    'team': {'id': 21,
#     'abbreviation': 'OKC',
#     'city': 'Oklahoma City',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Oklahoma City Thunder',
#     'name': 'Thunder'},
#    'weight_pounds': 200},
#   {'id': 119,
#    'first_name': 'Tyler',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Davis',
#    'position': 'C',
#    'team': {'id': 21,
#     'abbreviation': 'OKC',
#     'city': 'Oklahoma City',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Oklahoma City Thunder',
#     'name': 'Thunder'},
#    'weight_pounds': None},
#   {'id': 149,
#    'first_name': 'Keenan',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Evans',
#    'position': 'G',
#    'team': {'id': 9,
#     'abbreviation': 'DET',
#     'city': 'Detroit',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Detroit Pistons',
#     'name': 'Pistons'},
#    'weight_pounds': None},
#   {'id': 179,
#    'first_name': 'Marcin',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Gortat',
#    'position': 'C',
#    'team': {'id': 13,
#     'abbreviation': 'LAC',
#     'city': 'LA',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'LA Clippers',
#     'name': 'Clippers'},
#    'weight_pounds': None},
#   {'id': 1593,
#    'first_name': 'Andrew',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Bogut',
#    'position': 'F',
#    'team': {'id': 10,
#     'abbreviation': 'GSW',
#     'city': 'Golden State',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Golden State Warriors',
#     'name': 'Warriors'},
#    'weight_pounds': None},
#   {'id': 241,
#    'first_name': 'Amir',
#    'height_feet': 6,
#    'height_inches': 9,
#    'last_name': 'Johnson',
#    'position': 'C-F',
#    'team': {'id': 23,
#     'abbreviation': 'PHI',
#     'city': 'Philadelphia',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Philadelphia 76ers',
#     'name': '76ers'},
#    'weight_pounds': 240},
#   {'id': 392,
#    'first_name': 'Malachi',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Richardson',
#    'position': 'G',
#    'team': {'id': 29,
#     'abbreviation': 'UTA',
#     'city': 'Utah',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Utah Jazz',
#     'name': 'Jazz'},
#    'weight_pounds': None},
#   {'id': 281,
#    'first_name': 'Zach',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Lofton',
#    'position': 'G',
#    'team': {'id': 9,
#     'abbreviation': 'DET',
#     'city': 'Detroit',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Detroit Pistons',
#     'name': 'Pistons'},
#    'weight_pounds': None},
#   {'id': 263,
#    'first_name': 'Kosta',
#    'height_feet': 7,
#    'height_inches': 0,
#    'last_name': 'Koufos',
#    'position': 'C',
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'weight_pounds': 245},
#   {'id': 382,
#    'first_name': 'Billy',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Preston',
#    'position': 'F',
#    'team': {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    'weight_pounds': None},
#   {'id': 384,
#    'first_name': 'Zhou',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Qi',
#    'position': 'F-C',
#    'team': {'id': 11,
#     'abbreviation': 'HOU',
#     'city': 'Houston',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Houston Rockets',
#     'name': 'Rockets'},
#    'weight_pounds': None},
#   {'id': 388,
#    'first_name': 'Zach',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Randolph',
#    'position': 'F',
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'weight_pounds': None},
#   {'id': 430,
#    'first_name': 'DJ',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Stephens',
#    'position': 'G-F',
#    'team': {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    'weight_pounds': None},
#   {'id': 437,
#    'first_name': 'Milos',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Teodosic',
#    'position': 'G',
#    'team': {'id': 13,
#     'abbreviation': 'LAC',
#     'city': 'LA',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'LA Clippers',
#     'name': 'Clippers'},
#    'weight_pounds': None},
#   {'id': 448,
#    'first_name': 'Gary',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Trent Jr.',
#    'position': 'G',
#    'team': {'id': 25,
#     'abbreviation': 'POR',
#     'city': 'Portland',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Portland Trail Blazers',
#     'name': 'Trail Blazers'},
#    'weight_pounds': None},
#   {'id': 494,
#    'first_name': 'Michael',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Smith',
#    'position': '',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'weight_pounds': None},
#   {'id': 495,
#    'first_name': 'John',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Morton',
#    'position': '',
#    'team': {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    'weight_pounds': None},
#   {'id': 496,
#    'first_name': 'Howard',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Wright',
#    'position': '',
#    'team': {'id': 1,
#     'abbreviation': 'ATL',
#     'city': 'Atlanta',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Atlanta Hawks',
#     'name': 'Hawks'},
#    'weight_pounds': None},
#   {'id': 497,
#    'first_name': 'Michael',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Ansley',
#    'position': '',
#    'team': {'id': 22,
#     'abbreviation': 'ORL',
#     'city': 'Orlando',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Orlando Magic',
#     'name': 'Magic'},
#    'weight_pounds': None}],
#  'meta': {'total_pages': 151,
#   'current_page': 1,
#   'next_page': 2,
#   'per_page': 25,
#   'total_count': 3754}}

# %%
player_url = "https://www.balldontlie.io/api/v1/players"
player_api = requests.get(player_url).json()

# %%
url_query2 = "https://www.balldontlie.io/api/v1/teams"
teams_api = requests.get(url_query2).json()

# %%
url_query3 = "https://www.balldontlie.io/api/v1/games"
games_api = requests.get(url_query3).json()

# %%
url = "https://free-nba.p.rapidapi.com/stats"

headers = {
    'x-rapidapi-host': "free-nba.p.rapidapi.com",
    'x-rapidapi-key': API_KEY
    }

response = requests.request("GET", url, headers=headers)

# print(response.text)

stats_api = response.text

stats_data = json.loads(stats_api)
stats_data
# Out:
# {'data': [{'id': 1069008,
#    'ast': 0,
#    'blk': 1,
#    'dreb': 2,
#    'fg3_pct': 0.2,
#    'fg3a': 5,
#    'fg3m': 1,
#    'fg_pct': 0.333,
#    'fga': 9,
#    'fgm': 3,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '20:08',
#    'oreb': 0,
#    'pf': 0,
#    'player': {'id': 415,
#     'first_name': 'Iman',
#     'height_feet': 6,
#     'height_inches': 5,
#     'last_name': 'Shumpert',
#     'position': 'G',
#     'team_id': 3,
#     'weight_pounds': 215},
#    'pts': 7,
#    'reb': 2,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 2},
#   {'id': 1069009,
#    'ast': 4,
#    'blk': 0,
#    'dreb': 5,
#    'fg3_pct': 0.0,
#    'fg3a': 2,
#    'fg3m': 0,
#    'fg_pct': 0.2,
#    'fga': 5,
#    'fgm': 1,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '19:22',
#    'oreb': 1,
#    'pf': 1,
#    'player': {'id': 49,
#     'first_name': 'Nemanja',
#     'height_feet': 6,
#     'height_inches': 10,
#     'last_name': 'Bjelica',
#     'position': 'F',
#     'team_id': 10,
#     'weight_pounds': 234},
#    'pts': 2,
#    'reb': 6,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 0},
#   {'id': 1069010,
#    'ast': 4,
#    'blk': 1,
#    'dreb': 5,
#    'fg3_pct': 0.0,
#    'fg3a': 0,
#    'fg3m': 0,
#    'fg_pct': 0.667,
#    'fga': 6,
#    'fgm': 4,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '27:24',
#    'oreb': 6,
#    'pf': 2,
#    'player': {'id': 91,
#     'first_name': 'Willie',
#     'height_feet': 7,
#     'height_inches': 0,
#     'last_name': 'Cauley-Stein',
#     'position': 'C',
#     'team_id': 7,
#     'weight_pounds': 240},
#    'pts': 8,
#    'reb': 11,
#    'stl': 3,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 2},
#   {'id': 1069011,
#    'ast': 1,
#    'blk': 0,
#    'dreb': 1,
#    'fg3_pct': 0.545,
#    'fg3a': 11,
#    'fg3m': 6,
#    'fg_pct': 0.5,
#    'fga': 18,
#    'fgm': 9,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '32:06',
#    'oreb': 0,
#    'pf': 2,
#    'player': {'id': 210,
#     'first_name': 'Buddy',
#     'height_feet': 6,
#     'height_inches': 4,
#     'last_name': 'Hield',
#     'position': 'G',
#     'team_id': 26,
#     'weight_pounds': 214},
#    'pts': 24,
#    'reb': 1,
#    'stl': 2,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 0},
#   {'id': 1069012,
#    'ast': 8,
#    'blk': 1,
#    'dreb': 5,
#    'fg3_pct': 0.0,
#    'fg3a': 2,
#    'fg3m': 0,
#    'fg_pct': 0.4,
#    'fga': 10,
#    'fgm': 4,
#    'ft_pct': 0.667,
#    'fta': 3,
#    'ftm': 2,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '30:30',
#    'oreb': 0,
#    'pf': 4,
#    'player': {'id': 161,
#     'first_name': "De'Aaron",
#     'height_feet': 6,
#     'height_inches': 3,
#     'last_name': 'Fox',
#     'position': 'G',
#     'team_id': 26,
#     'weight_pounds': 175},
#    'pts': 10,
#    'reb': 5,
#    'stl': 1,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 4},
#   {'id': 1069013,
#    'ast': 2,
#    'blk': 0,
#    'dreb': 1,
#    'fg3_pct': 0.5,
#    'fg3a': 2,
#    'fg3m': 1,
#    'fg_pct': 0.615,
#    'fga': 13,
#    'fgm': 8,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '27:20',
#    'oreb': 0,
#    'pf': 2,
#    'player': {'id': 53,
#     'first_name': 'Bogdan',
#     'height_feet': 6,
#     'height_inches': 6,
#     'last_name': 'Bogdanovic',
#     'position': 'G',
#     'team_id': 1,
#     'weight_pounds': 205},
#    'pts': 17,
#    'reb': 1,
#    'stl': 1,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 2},
#   {'id': 1069014,
#    'ast': 2,
#    'blk': 0,
#    'dreb': 1,
#    'fg3_pct': 0.333,
#    'fg3a': 3,
#    'fg3m': 1,
#    'fg_pct': 0.4,
#    'fga': 5,
#    'fgm': 2,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '16:22',
#    'oreb': 0,
#    'pf': 1,
#    'player': {'id': 157,
#     'first_name': 'Yogi',
#     'height_feet': 6,
#     'height_inches': 0,
#     'last_name': 'Ferrell',
#     'position': 'G',
#     'team_id': 13,
#     'weight_pounds': 180},
#    'pts': 5,
#    'reb': 1,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 0},
#   {'id': 1069015,
#    'ast': 1,
#    'blk': 0,
#    'dreb': 4,
#    'fg3_pct': 0.5,
#    'fg3a': 2,
#    'fg3m': 1,
#    'fg_pct': 0.545,
#    'fga': 11,
#    'fgm': 6,
#    'ft_pct': 0.5,
#    'fta': 4,
#    'ftm': 2,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '22:55',
#    'oreb': 4,
#    'pf': 2,
#    'player': {'id': 24,
#     'first_name': 'Marvin',
#     'height_feet': 6,
#     'height_inches': 11,
#     'last_name': 'Bagley III',
#     'position': 'F',
#     'team_id': 26,
#     'weight_pounds': 234},
#    'pts': 15,
#    'reb': 8,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 3},
#   {'id': 1069016,
#    'ast': 2,
#    'blk': 0,
#    'dreb': 3,
#    'fg3_pct': 0.25,
#    'fg3a': 4,
#    'fg3m': 1,
#    'fg_pct': 0.4,
#    'fga': 5,
#    'fgm': 2,
#    'ft_pct': 0.5,
#    'fta': 2,
#    'ftm': 1,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '24:07',
#    'oreb': 0,
#    'pf': 2,
#    'player': {'id': 235,
#     'first_name': 'Justin',
#     'height_feet': 6,
#     'height_inches': 8,
#     'last_name': 'Jackson',
#     'position': 'F',
#     'team_id': 24,
#     'weight_pounds': 210},
#    'pts': 6,
#    'reb': 3,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 0},
#   {'id': 1069017,
#    'ast': 4,
#    'blk': 0,
#    'dreb': 4,
#    'fg3_pct': 0.0,
#    'fg3a': 0,
#    'fg3m': 0,
#    'fg_pct': 0.0,
#    'fga': 3,
#    'fgm': 0,
#    'ft_pct': 0.25,
#    'fta': 4,
#    'ftm': 1,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '16:14',
#    'oreb': 0,
#    'pf': 6,
#    'player': {'id': 174,
#     'first_name': 'Harry',
#     'height_feet': 6,
#     'height_inches': 10,
#     'last_name': 'Giles III',
#     'position': 'F-C',
#     'team_id': 13,
#     'weight_pounds': 240},
#    'pts': 1,
#    'reb': 4,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 4},
#   {'id': 1069018,
#    'ast': 0,
#    'blk': 0,
#    'dreb': 0,
#    'fg3_pct': 0.0,
#    'fg3a': 0,
#    'fg3m': 0,
#    'fg_pct': 0.0,
#    'fga': 0,
#    'fgm': 0,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '1:46',
#    'oreb': 0,
#    'pf': 0,
#    'player': {'id': 299,
#     'first_name': 'Frank',
#     'height_feet': 5,
#     'height_inches': 11,
#     'last_name': 'Mason',
#     'position': 'G',
#     'team_id': 23,
#     'weight_pounds': 190},
#    'pts': 0,
#    'reb': 0,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 0},
#   {'id': 1069019,
#    'ast': 0,
#    'blk': 0,
#    'dreb': 0,
#    'fg3_pct': 0.0,
#    'fg3a': 2,
#    'fg3m': 0,
#    'fg_pct': 0.0,
#    'fga': 3,
#    'fgm': 0,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '1:46',
#    'oreb': 0,
#    'pf': 0,
#    'player': {'id': 309,
#     'first_name': 'Ben',
#     'height_feet': None,
#     'height_inches': None,
#     'last_name': 'McLemore',
#     'position': 'G',
#     'team_id': 25,
#     'weight_pounds': None},
#    'pts': 0,
#    'reb': 0,
#    'stl': 0,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': 0},
#   {'id': 1069020,
#    'ast': None,
#    'blk': None,
#    'dreb': None,
#    'fg3_pct': None,
#    'fg3a': None,
#    'fg3m': None,
#    'fg_pct': None,
#    'fga': None,
#    'fgm': None,
#    'ft_pct': None,
#    'fta': None,
#    'ftm': None,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': None,
#    'oreb': None,
#    'pf': None,
#    'player': {'id': 263,
#     'first_name': 'Kosta',
#     'height_feet': 7,
#     'height_inches': 0,
#     'last_name': 'Koufos',
#     'position': 'C',
#     'team_id': 26,
#     'weight_pounds': 245},
#    'pts': None,
#    'reb': None,
#    'stl': None,
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'turnover': None},
#   {'id': 1069021,
#    'ast': 3,
#    'blk': 0,
#    'dreb': 4,
#    'fg3_pct': 0.0,
#    'fg3a': 2,
#    'fg3m': 0,
#    'fg_pct': 0.2,
#    'fga': 5,
#    'fgm': 1,
#    'ft_pct': 0.833,
#    'fta': 6,
#    'ftm': 5,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '26:43',
#    'oreb': 1,
#    'pf': 3,
#    'player': {'id': 33,
#     'first_name': 'Nicolas',
#     'height_feet': 6,
#     'height_inches': 8,
#     'last_name': 'Batum',
#     'position': 'F-G',
#     'team_id': 13,
#     'weight_pounds': 200},
#    'pts': 7,
#    'reb': 5,
#    'stl': 2,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 3},
#   {'id': 1069022,
#    'ast': 2,
#    'blk': 1,
#    'dreb': 5,
#    'fg3_pct': 0.5,
#    'fg3a': 6,
#    'fg3m': 3,
#    'fg_pct': 0.5,
#    'fga': 6,
#    'fgm': 3,
#    'ft_pct': 0.5,
#    'fta': 2,
#    'ftm': 1,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '29:30',
#    'oreb': 0,
#    'pf': 2,
#    'player': {'id': 482,
#     'first_name': 'Marvin',
#     'height_feet': 6,
#     'height_inches': 9,
#     'last_name': 'Williams',
#     'position': 'F',
#     'team_id': 17,
#     'weight_pounds': 237},
#    'pts': 10,
#    'reb': 5,
#    'stl': 3,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 0},
#   {'id': 1069023,
#    'ast': 0,
#    'blk': 1,
#    'dreb': 1,
#    'fg3_pct': 0.0,
#    'fg3a': 0,
#    'fg3m': 0,
#    'fg_pct': 0.0,
#    'fga': 0,
#    'fgm': 0,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '9:25',
#    'oreb': 1,
#    'pf': 0,
#    'player': {'id': 48,
#     'first_name': 'Bismack',
#     'height_feet': 6,
#     'height_inches': 9,
#     'last_name': 'Biyombo',
#     'position': 'C',
#     'team_id': 24,
#     'weight_pounds': 255},
#    'pts': 0,
#    'reb': 2,
#    'stl': 0,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 0},
#   {'id': 1069024,
#    'ast': 1,
#    'blk': 0,
#    'dreb': 4,
#    'fg3_pct': 0.286,
#    'fg3a': 7,
#    'fg3m': 2,
#    'fg_pct': 0.357,
#    'fga': 14,
#    'fgm': 5,
#    'ft_pct': 1.0,
#    'fta': 2,
#    'ftm': 2,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '26:19',
#    'oreb': 1,
#    'pf': 1,
#    'player': {'id': 267,
#     'first_name': 'Jeremy',
#     'height_feet': 6,
#     'height_inches': 5,
#     'last_name': 'Lamb',
#     'position': 'G',
#     'team_id': 12,
#     'weight_pounds': 185},
#    'pts': 14,
#    'reb': 5,
#    'stl': 2,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 3},
#   {'id': 1069025,
#    'ast': 5,
#    'blk': 1,
#    'dreb': 2,
#    'fg3_pct': 0.3,
#    'fg3a': 10,
#    'fg3m': 3,
#    'fg_pct': 0.429,
#    'fga': 21,
#    'fgm': 9,
#    'ft_pct': 1.0,
#    'fta': 2,
#    'ftm': 2,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '28:42',
#    'oreb': 2,
#    'pf': 0,
#    'player': {'id': 465,
#     'first_name': 'Kemba',
#     'height_feet': 6,
#     'height_inches': 1,
#     'last_name': 'Walker',
#     'position': 'G',
#     'team_id': 20,
#     'weight_pounds': 184},
#    'pts': 23,
#    'reb': 4,
#    'stl': 0,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 2},
#   {'id': 1069026,
#    'ast': 1,
#    'blk': 1,
#    'dreb': 12,
#    'fg3_pct': 0.5,
#    'fg3a': 2,
#    'fg3m': 1,
#    'fg_pct': 0.444,
#    'fga': 9,
#    'fgm': 4,
#    'ft_pct': 1.0,
#    'fta': 2,
#    'ftm': 2,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '25:30',
#    'oreb': 4,
#    'pf': 4,
#    'player': {'id': 207,
#     'first_name': 'Willy',
#     'height_feet': 6,
#     'height_inches': 11,
#     'last_name': 'Hernangomez',
#     'position': 'C',
#     'team_id': 19,
#     'weight_pounds': 240},
#    'pts': 11,
#    'reb': 16,
#    'stl': 1,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 1},
#   {'id': 1069027,
#    'ast': 1,
#    'blk': 0,
#    'dreb': 3,
#    'fg3_pct': 0.333,
#    'fg3a': 3,
#    'fg3m': 1,
#    'fg_pct': 0.667,
#    'fga': 9,
#    'fgm': 6,
#    'ft_pct': 0.5,
#    'fta': 4,
#    'ftm': 2,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '22:20',
#    'oreb': 1,
#    'pf': 0,
#    'player': {'id': 62,
#     'first_name': 'Miles',
#     'height_feet': 6,
#     'height_inches': 7,
#     'last_name': 'Bridges',
#     'position': 'F',
#     'team_id': 4,
#     'weight_pounds': 225},
#    'pts': 15,
#    'reb': 4,
#    'stl': 0,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 0},
#   {'id': 1069028,
#    'ast': 1,
#    'blk': 0,
#    'dreb': 1,
#    'fg3_pct': 0.0,
#    'fg3a': 2,
#    'fg3m': 0,
#    'fg_pct': 0.571,
#    'fga': 7,
#    'fgm': 4,
#    'ft_pct': 1.0,
#    'fta': 7,
#    'ftm': 7,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '30:15',
#    'oreb': 1,
#    'pf': 2,
#    'player': {'id': 255,
#     'first_name': 'Michael',
#     'height_feet': 6,
#     'height_inches': 7,
#     'last_name': 'Kidd-Gilchrist',
#     'position': 'F',
#     'team_id': 7,
#     'weight_pounds': 232},
#    'pts': 15,
#    'reb': 2,
#    'stl': 2,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 0},
#   {'id': 1069029,
#    'ast': 0,
#    'blk': 0,
#    'dreb': 0,
#    'fg3_pct': 0.0,
#    'fg3a': 3,
#    'fg3m': 0,
#    'fg_pct': 0.0,
#    'fga': 3,
#    'fgm': 0,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '9:14',
#    'oreb': 0,
#    'pf': 0,
#    'player': {'id': 180,
#     'first_name': "Devonte'",
#     'height_feet': 6,
#     'height_inches': 2,
#     'last_name': 'Graham',
#     'position': 'G',
#     'team_id': 19,
#     'weight_pounds': 185},
#    'pts': 0,
#    'reb': 0,
#    'stl': 0,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 0},
#   {'id': 1069030,
#    'ast': 6,
#    'blk': 0,
#    'dreb': 1,
#    'fg3_pct': 0.0,
#    'fg3a': 1,
#    'fg3m': 0,
#    'fg_pct': 0.5,
#    'fga': 10,
#    'fgm': 5,
#    'ft_pct': 1.0,
#    'fta': 4,
#    'ftm': 4,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '17:32',
#    'oreb': 1,
#    'pf': 3,
#    'player': {'id': 363,
#     'first_name': 'Tony',
#     'height_feet': 6,
#     'height_inches': 2,
#     'last_name': 'Parker',
#     'position': 'G',
#     'team_id': 4,
#     'weight_pounds': 185},
#    'pts': 14,
#    'reb': 2,
#    'stl': 1,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 2},
#   {'id': 1069031,
#    'ast': 1,
#    'blk': 0,
#    'dreb': 1,
#    'fg3_pct': 0.5,
#    'fg3a': 2,
#    'fg3m': 1,
#    'fg_pct': 0.667,
#    'fga': 3,
#    'fgm': 2,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '13:10',
#    'oreb': 0,
#    'pf': 1,
#    'player': {'id': 324,
#     'first_name': 'Malik',
#     'height_feet': 6,
#     'height_inches': 3,
#     'last_name': 'Monk',
#     'position': 'G',
#     'team_id': 14,
#     'weight_pounds': 200},
#    'pts': 5,
#    'reb': 1,
#    'stl': 0,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 2},
#   {'id': 1069032,
#    'ast': 0,
#    'blk': 0,
#    'dreb': 0,
#    'fg3_pct': 0.0,
#    'fg3a': 0,
#    'fg3m': 0,
#    'fg_pct': 0.0,
#    'fga': 0,
#    'fgm': 0,
#    'ft_pct': 0.0,
#    'fta': 0,
#    'ftm': 0,
#    'game': {'id': 45237,
#     'date': '2019-01-17T00:00:00.000Z',
#     'home_team_id': 4,
#     'home_team_score': 114,
#     'period': 4,
#     'postseason': False,
#     'season': 2018,
#     'status': 'Final',
#     'time': ' ',
#     'visitor_team_id': 26,
#     'visitor_team_score': 95},
#    'min': '1:20',
#    'oreb': 0,
#    'pf': 0,
#    'player': {'id': 23,
#     'first_name': 'Dwayne',
#     'height_feet': 6,
#     'height_inches': 7,
#     'last_name': 'Bacon',
#     'position': 'G-F',
#     'team_id': 20,
#     'weight_pounds': 221},
#    'pts': 0,
#    'reb': 0,
#    'stl': 0,
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'turnover': 0}],
#  'meta': {'total_pages': 46561,
#   'current_page': 1,
#   'next_page': 2,
#   'per_page': 25,
#   'total_count': 1164016}}

# %%
stats_df["game.season"]
# Out:
# 0     2018
# 1     2018
# 2     2018
# 3     2018
# 4     2018
# 5     2018
# 6     2018
# 7     2018
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2018
# 13    2018
# 14    2018
# 15    2018
# 16    2018
# 17    2018
# 18    2018
# 19    2018
# 20    2018
# 21    2018
# 22    2018
# 23    2018
# 24    2018
# Name: game.season, dtype: int64

# %%
nba_seasons = list(range(1990, 2022))

# %%
for page in nba_seasons:
    url = "https://free-nba.p.rapidapi.com/stats"

    querystring = {"seasons":int(page)}

    headers = {
        'x-rapidapi-host': "free-nba.p.rapidapi.com",
        'x-rapidapi-key': API_KEY
        }

    response = requests.request("GET", url, headers=headers, params=querystring)

    # print(response.text)

    stats_api = response.text

    stats_data = json.loads(stats_api)
    stats_data

# %%
stats_df = pd.json_normalize(stats_data, record_path =['data'])
stats_df

# %%
# ****we need to give parameters to Run this API not sure how we want to use this API****
# url_query5 = "https://www.balldontlie.io/api/v1/season_averages"
url_query5 = "https://www.balldontlie.io/api/v1/season_averages?season=2018&player_ids[]=1&player_ids[]=2"
season_avg_api = requests.get(url_query5).json()

# %%
season_avg_api
# Out:
# {'data': [{'games_played': 31,
#    'player_id': 1,
#    'season': 2018,
#    'min': '18:50',
#    'fgm': 1.74,
#    'fga': 5.0,
#    'fg3m': 1.26,
#    'fg3a': 4.03,
#    'ftm': 0.39,
#    'fta': 0.42,
#    'oreb': 0.16,
#    'dreb': 1.39,
#    'reb': 1.55,
#    'ast': 0.65,
#    'stl': 0.55,
#    'blk': 0.19,
#    'turnover': 0.45,
#    'pf': 1.68,
#    'pts': 5.13,
#    'fg_pct': 0.348,
#    'fg3_pct': 0.312,
#    'ft_pct': 0.923},
#   {'games_played': 34,
#    'player_id': 2,
#    'season': 2018,
#    'min': '12:34',
#    'fgm': 1.12,
#    'fga': 3.24,
#    'fg3m': 0.74,
#    'fg3a': 2.18,
#    'ftm': 0.21,
#    'fta': 0.26,
#    'oreb': 0.32,
#    'dreb': 1.47,
#    'reb': 1.79,
#    'ast': 1.94,
#    'stl': 0.38,
#    'blk': 0.15,
#    'turnover': 0.82,
#    'pf': 1.32,
#    'pts': 3.18,
#    'fg_pct': 0.345,
#    'fg3_pct': 0.338,
#    'ft_pct': 0.778}]}

# %%
player_api
# Out:
# {'data': [{'id': 14,
#    'first_name': 'Ike',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Anigbogu',
#    'position': 'C',
#    'team': {'id': 12,
#     'abbreviation': 'IND',
#     'city': 'Indiana',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Indiana Pacers',
#     'name': 'Pacers'},
#    'weight_pounds': None},
#   {'id': 25,
#    'first_name': 'Ron',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Baker',
#    'position': 'G',
#    'team': {'id': 20,
#     'abbreviation': 'NYK',
#     'city': 'New York',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'New York Knicks',
#     'name': 'Knicks'},
#    'weight_pounds': None},
#   {'id': 47,
#    'first_name': 'Jabari',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Bird',
#    'position': 'G',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'weight_pounds': None},
#   {'id': 67,
#    'first_name': 'MarShon',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Brooks',
#    'position': 'G',
#    'team': {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    'weight_pounds': None},
#   {'id': 71,
#    'first_name': 'Lorenzo',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Brown',
#    'position': 'G',
#    'team': {'id': 28,
#     'abbreviation': 'TOR',
#     'city': 'Toronto',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Toronto Raptors',
#     'name': 'Raptors'},
#    'weight_pounds': None},
#   {'id': 90,
#    'first_name': 'Omri',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Casspi',
#    'position': 'F',
#    'team': {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    'weight_pounds': None},
#   {'id': 1,
#    'first_name': 'Alex',
#    'height_feet': 6,
#    'height_inches': 6,
#    'last_name': 'Abrines',
#    'position': 'G',
#    'team': {'id': 21,
#     'abbreviation': 'OKC',
#     'city': 'Oklahoma City',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Oklahoma City Thunder',
#     'name': 'Thunder'},
#    'weight_pounds': 200},
#   {'id': 119,
#    'first_name': 'Tyler',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Davis',
#    'position': 'C',
#    'team': {'id': 21,
#     'abbreviation': 'OKC',
#     'city': 'Oklahoma City',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Oklahoma City Thunder',
#     'name': 'Thunder'},
#    'weight_pounds': None},
#   {'id': 149,
#    'first_name': 'Keenan',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Evans',
#    'position': 'G',
#    'team': {'id': 9,
#     'abbreviation': 'DET',
#     'city': 'Detroit',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Detroit Pistons',
#     'name': 'Pistons'},
#    'weight_pounds': None},
#   {'id': 179,
#    'first_name': 'Marcin',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Gortat',
#    'position': 'C',
#    'team': {'id': 13,
#     'abbreviation': 'LAC',
#     'city': 'LA',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'LA Clippers',
#     'name': 'Clippers'},
#    'weight_pounds': None},
#   {'id': 1593,
#    'first_name': 'Andrew',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Bogut',
#    'position': 'F',
#    'team': {'id': 10,
#     'abbreviation': 'GSW',
#     'city': 'Golden State',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Golden State Warriors',
#     'name': 'Warriors'},
#    'weight_pounds': None},
#   {'id': 241,
#    'first_name': 'Amir',
#    'height_feet': 6,
#    'height_inches': 9,
#    'last_name': 'Johnson',
#    'position': 'C-F',
#    'team': {'id': 23,
#     'abbreviation': 'PHI',
#     'city': 'Philadelphia',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Philadelphia 76ers',
#     'name': '76ers'},
#    'weight_pounds': 240},
#   {'id': 392,
#    'first_name': 'Malachi',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Richardson',
#    'position': 'G',
#    'team': {'id': 29,
#     'abbreviation': 'UTA',
#     'city': 'Utah',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Utah Jazz',
#     'name': 'Jazz'},
#    'weight_pounds': None},
#   {'id': 281,
#    'first_name': 'Zach',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Lofton',
#    'position': 'G',
#    'team': {'id': 9,
#     'abbreviation': 'DET',
#     'city': 'Detroit',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Detroit Pistons',
#     'name': 'Pistons'},
#    'weight_pounds': None},
#   {'id': 263,
#    'first_name': 'Kosta',
#    'height_feet': 7,
#    'height_inches': 0,
#    'last_name': 'Koufos',
#    'position': 'C',
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'weight_pounds': 245},
#   {'id': 382,
#    'first_name': 'Billy',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Preston',
#    'position': 'F',
#    'team': {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    'weight_pounds': None},
#   {'id': 384,
#    'first_name': 'Zhou',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Qi',
#    'position': 'F-C',
#    'team': {'id': 11,
#     'abbreviation': 'HOU',
#     'city': 'Houston',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Houston Rockets',
#     'name': 'Rockets'},
#    'weight_pounds': None},
#   {'id': 388,
#    'first_name': 'Zach',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Randolph',
#    'position': 'F',
#    'team': {'id': 26,
#     'abbreviation': 'SAC',
#     'city': 'Sacramento',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Sacramento Kings',
#     'name': 'Kings'},
#    'weight_pounds': None},
#   {'id': 430,
#    'first_name': 'DJ',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Stephens',
#    'position': 'G-F',
#    'team': {'id': 15,
#     'abbreviation': 'MEM',
#     'city': 'Memphis',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Memphis Grizzlies',
#     'name': 'Grizzlies'},
#    'weight_pounds': None},
#   {'id': 437,
#    'first_name': 'Milos',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Teodosic',
#    'position': 'G',
#    'team': {'id': 13,
#     'abbreviation': 'LAC',
#     'city': 'LA',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'LA Clippers',
#     'name': 'Clippers'},
#    'weight_pounds': None},
#   {'id': 448,
#    'first_name': 'Gary',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Trent Jr.',
#    'position': 'G',
#    'team': {'id': 25,
#     'abbreviation': 'POR',
#     'city': 'Portland',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Portland Trail Blazers',
#     'name': 'Trail Blazers'},
#    'weight_pounds': None},
#   {'id': 494,
#    'first_name': 'Michael',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Smith',
#    'position': '',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'weight_pounds': None},
#   {'id': 495,
#    'first_name': 'John',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Morton',
#    'position': '',
#    'team': {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    'weight_pounds': None},
#   {'id': 496,
#    'first_name': 'Howard',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Wright',
#    'position': '',
#    'team': {'id': 1,
#     'abbreviation': 'ATL',
#     'city': 'Atlanta',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Atlanta Hawks',
#     'name': 'Hawks'},
#    'weight_pounds': None},
#   {'id': 497,
#    'first_name': 'Michael',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Ansley',
#    'position': '',
#    'team': {'id': 22,
#     'abbreviation': 'ORL',
#     'city': 'Orlando',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Orlando Magic',
#     'name': 'Magic'},
#    'weight_pounds': None}],
#  'meta': {'total_pages': 151,
#   'current_page': 1,
#   'next_page': 2,
#   'per_page': 25,
#   'total_count': 3754}}

# %%
player_df = pd.json_normalize(player_api, record_path =['data'])
player_df
# Out:
#       id first_name  height_feet  height_inches   last_name position  \
# 0     14        Ike          NaN            NaN    Anigbogu        C
# 1     25        Ron          NaN            NaN       Baker        G
# 2     47     Jabari          NaN            NaN        Bird        G
# 3     67    MarShon          NaN            NaN      Brooks        G
# 4     71    Lorenzo          NaN            NaN       Brown        G
# 5     90       Omri          NaN            NaN      Casspi        F
# 6      1       Alex          6.0            6.0     Abrines        G
# 7    119      Tyler          NaN            NaN       Davis        C
# 8    149     Keenan          NaN            NaN       Evans        G
# 9    179     Marcin          NaN            NaN      Gortat        C
# 10  1593     Andrew          NaN            NaN       Bogut        F
# 11   241       Amir          6.0            9.0     Johnson      C-F
# 12   392    Malachi          NaN            NaN  Richardson        G
# 13   281       Zach          NaN            NaN      Lofton        G
# 14   263      Kosta          7.0            0.0      Koufos        C
# 15   382      Billy          NaN            NaN     Preston        F
# 16   384       Zhou          NaN            NaN          Qi      F-C
# 17   388       Zach          NaN            NaN    Randolph        F
# 18   430         DJ          NaN            NaN    Stephens      G-F
# 19   437      Milos          NaN            NaN    Teodosic        G
# 20   448       Gary          NaN            NaN   Trent Jr.        G
# 21   494    Michael          NaN            NaN       Smith
# 22   495       John          NaN            NaN      Morton
# 23   496     Howard          NaN            NaN      Wright
# 24   497    Michael          NaN            NaN      Ansley
#
#     weight_pounds  team.id team.abbreviation      team.city team.conference  \
# 0             NaN       12               IND        Indiana            East
# 1             NaN       20               NYK       New York            East
# 2             NaN        2               BOS         Boston            East
# 3             NaN       15               MEM        Memphis            West
# 4             NaN       28               TOR        Toronto            East
# 5             NaN       15               MEM        Memphis            West
# 6           200.0       21               OKC  Oklahoma City            West
# 7             NaN       21               OKC  Oklahoma City            West
# 8             NaN        9               DET        Detroit            East
# 9             NaN       13               LAC             LA            West
# 10            NaN       10               GSW   Golden State            West
# 11          240.0       23               PHI   Philadelphia            East
# 12            NaN       29               UTA           Utah            West
# 13            NaN        9               DET        Detroit            East
# 14          245.0       26               SAC     Sacramento            West
# 15            NaN        6               CLE      Cleveland            East
# 16            NaN       11               HOU        Houston            West
# 17            NaN       26               SAC     Sacramento            West
# 18            NaN       15               MEM        Memphis            West
# 19            NaN       13               LAC             LA            West
# 20            NaN       25               POR       Portland            West
# 21            NaN        2               BOS         Boston            East
# 22            NaN        6               CLE      Cleveland            East
# 23            NaN        1               ATL        Atlanta            East
# 24            NaN       22               ORL        Orlando            East
#
#    team.division          team.full_name      team.name
# 0        Central          Indiana Pacers         Pacers
# 1       Atlantic         New York Knicks         Knicks
# 2       Atlantic          Boston Celtics        Celtics
# 3      Southwest       Memphis Grizzlies      Grizzlies
# 4       Atlantic         Toronto Raptors        Raptors
# 5      Southwest       Memphis Grizzlies      Grizzlies
# 6      Northwest   Oklahoma City Thunder        Thunder
# 7      Northwest   Oklahoma City Thunder        Thunder
# 8        Central         Detroit Pistons        Pistons
# 9        Pacific             LA Clippers       Clippers
# 10       Pacific   Golden State Warriors       Warriors
# 11      Atlantic      Philadelphia 76ers          76ers
# 12     Northwest               Utah Jazz           Jazz
# 13       Central         Detroit Pistons        Pistons
# 14       Pacific        Sacramento Kings          Kings
# 15       Central     Cleveland Cavaliers      Cavaliers
# 16     Southwest         Houston Rockets        Rockets
# 17       Pacific        Sacramento Kings          Kings
# 18     Southwest       Memphis Grizzlies      Grizzlies
# 19       Pacific             LA Clippers       Clippers
# 20     Northwest  Portland Trail Blazers  Trail Blazers
# 21      Atlantic          Boston Celtics        Celtics
# 22       Central     Cleveland Cavaliers      Cavaliers
# 23     Southeast           Atlanta Hawks          Hawks
# 24     Southeast           Orlando Magic          Magic

# %%
player_df.drop(['weight_pounds','team.abbreviation','team.city','team.conference','team.division','team.name'], axis=1, inplace=True)

# %%
player_df
# Out:
#       id first_name  height_feet  height_inches   last_name position  team.id  \
# 0     14        Ike          NaN            NaN    Anigbogu        C       12
# 1     25        Ron          NaN            NaN       Baker        G       20
# 2     47     Jabari          NaN            NaN        Bird        G        2
# 3     67    MarShon          NaN            NaN      Brooks        G       15
# 4     71    Lorenzo          NaN            NaN       Brown        G       28
# 5     90       Omri          NaN            NaN      Casspi        F       15
# 6      1       Alex          6.0            6.0     Abrines        G       21
# 7    119      Tyler          NaN            NaN       Davis        C       21
# 8    149     Keenan          NaN            NaN       Evans        G        9
# 9    179     Marcin          NaN            NaN      Gortat        C       13
# 10  1593     Andrew          NaN            NaN       Bogut        F       10
# 11   241       Amir          6.0            9.0     Johnson      C-F       23
# 12   392    Malachi          NaN            NaN  Richardson        G       29
# 13   281       Zach          NaN            NaN      Lofton        G        9
# 14   263      Kosta          7.0            0.0      Koufos        C       26
# 15   382      Billy          NaN            NaN     Preston        F        6
# 16   384       Zhou          NaN            NaN          Qi      F-C       11
# 17   388       Zach          NaN            NaN    Randolph        F       26
# 18   430         DJ          NaN            NaN    Stephens      G-F       15
# 19   437      Milos          NaN            NaN    Teodosic        G       13
# 20   448       Gary          NaN            NaN   Trent Jr.        G       25
# 21   494    Michael          NaN            NaN       Smith                 2
# 22   495       John          NaN            NaN      Morton                 6
# 23   496     Howard          NaN            NaN      Wright                 1
# 24   497    Michael          NaN            NaN      Ansley                22
#
#             team.full_name
# 0           Indiana Pacers
# 1          New York Knicks
# 2           Boston Celtics
# 3        Memphis Grizzlies
# 4          Toronto Raptors
# 5        Memphis Grizzlies
# 6    Oklahoma City Thunder
# 7    Oklahoma City Thunder
# 8          Detroit Pistons
# 9              LA Clippers
# 10   Golden State Warriors
# 11      Philadelphia 76ers
# 12               Utah Jazz
# 13         Detroit Pistons
# 14        Sacramento Kings
# 15     Cleveland Cavaliers
# 16         Houston Rockets
# 17        Sacramento Kings
# 18       Memphis Grizzlies
# 19             LA Clippers
# 20  Portland Trail Blazers
# 21          Boston Celtics
# 22     Cleveland Cavaliers
# 23           Atlanta Hawks
# 24           Orlando Magic

# %%
player_df.drop(['height_feet', 'height_inches'], axis=1, inplace=True)

# %%
player_df
# Out:
#       id first_name   last_name position  team.id          team.full_name
# 0     14        Ike    Anigbogu        C       12          Indiana Pacers
# 1     25        Ron       Baker        G       20         New York Knicks
# 2     47     Jabari        Bird        G        2          Boston Celtics
# 3     67    MarShon      Brooks        G       15       Memphis Grizzlies
# 4     71    Lorenzo       Brown        G       28         Toronto Raptors
# 5     90       Omri      Casspi        F       15       Memphis Grizzlies
# 6      1       Alex     Abrines        G       21   Oklahoma City Thunder
# 7    119      Tyler       Davis        C       21   Oklahoma City Thunder
# 8    149     Keenan       Evans        G        9         Detroit Pistons
# 9    179     Marcin      Gortat        C       13             LA Clippers
# 10  1593     Andrew       Bogut        F       10   Golden State Warriors
# 11   241       Amir     Johnson      C-F       23      Philadelphia 76ers
# 12   392    Malachi  Richardson        G       29               Utah Jazz
# 13   281       Zach      Lofton        G        9         Detroit Pistons
# 14   263      Kosta      Koufos        C       26        Sacramento Kings
# 15   382      Billy     Preston        F        6     Cleveland Cavaliers
# 16   384       Zhou          Qi      F-C       11         Houston Rockets
# 17   388       Zach    Randolph        F       26        Sacramento Kings
# 18   430         DJ    Stephens      G-F       15       Memphis Grizzlies
# 19   437      Milos    Teodosic        G       13             LA Clippers
# 20   448       Gary   Trent Jr.        G       25  Portland Trail Blazers
# 21   494    Michael       Smith                 2          Boston Celtics
# 22   495       John      Morton                 6     Cleveland Cavaliers
# 23   496     Howard      Wright                 1           Atlanta Hawks
# 24   497    Michael      Ansley                22           Orlando Magic

# %%
player_final_df = player_df
player_final_df
# Out:
#       id first_name   last_name position  team.id          team.full_name
# 0     14        Ike    Anigbogu        C       12          Indiana Pacers
# 1     25        Ron       Baker        G       20         New York Knicks
# 2     47     Jabari        Bird        G        2          Boston Celtics
# 3     67    MarShon      Brooks        G       15       Memphis Grizzlies
# 4     71    Lorenzo       Brown        G       28         Toronto Raptors
# 5     90       Omri      Casspi        F       15       Memphis Grizzlies
# 6      1       Alex     Abrines        G       21   Oklahoma City Thunder
# 7    119      Tyler       Davis        C       21   Oklahoma City Thunder
# 8    149     Keenan       Evans        G        9         Detroit Pistons
# 9    179     Marcin      Gortat        C       13             LA Clippers
# 10  1593     Andrew       Bogut        F       10   Golden State Warriors
# 11   241       Amir     Johnson      C-F       23      Philadelphia 76ers
# 12   392    Malachi  Richardson        G       29               Utah Jazz
# 13   281       Zach      Lofton        G        9         Detroit Pistons
# 14   263      Kosta      Koufos        C       26        Sacramento Kings
# 15   382      Billy     Preston        F        6     Cleveland Cavaliers
# 16   384       Zhou          Qi      F-C       11         Houston Rockets
# 17   388       Zach    Randolph        F       26        Sacramento Kings
# 18   430         DJ    Stephens      G-F       15       Memphis Grizzlies
# 19   437      Milos    Teodosic        G       13             LA Clippers
# 20   448       Gary   Trent Jr.        G       25  Portland Trail Blazers
# 21   494    Michael       Smith                 2          Boston Celtics
# 22   495       John      Morton                 6     Cleveland Cavaliers
# 23   496     Howard      Wright                 1           Atlanta Hawks
# 24   497    Michael      Ansley                22           Orlando Magic

# %%
player_final_df2 = player_final_df.rename(columns={'id': 'player_id', 'position': 'positions', 'team.id':'team_id', 'team.full_name':'team_full_name'})
player_final_df2
# Out:
#     player_id first_name   last_name positions  team_id  \
# 0          14        Ike    Anigbogu         C       12
# 1          25        Ron       Baker         G       20
# 2          47     Jabari        Bird         G        2
# 3          67    MarShon      Brooks         G       15
# 4          71    Lorenzo       Brown         G       28
# 5          90       Omri      Casspi         F       15
# 6           1       Alex     Abrines         G       21
# 7         119      Tyler       Davis         C       21
# 8         149     Keenan       Evans         G        9
# 9         179     Marcin      Gortat         C       13
# 10       1593     Andrew       Bogut         F       10
# 11        241       Amir     Johnson       C-F       23
# 12        392    Malachi  Richardson         G       29
# 13        281       Zach      Lofton         G        9
# 14        263      Kosta      Koufos         C       26
# 15        382      Billy     Preston         F        6
# 16        384       Zhou          Qi       F-C       11
# 17        388       Zach    Randolph         F       26
# 18        430         DJ    Stephens       G-F       15
# 19        437      Milos    Teodosic         G       13
# 20        448       Gary   Trent Jr.         G       25
# 21        494    Michael       Smith                  2
# 22        495       John      Morton                  6
# 23        496     Howard      Wright                  1
# 24        497    Michael      Ansley                 22
#
#             team_full_name
# 0           Indiana Pacers
# 1          New York Knicks
# 2           Boston Celtics
# 3        Memphis Grizzlies
# 4          Toronto Raptors
# 5        Memphis Grizzlies
# 6    Oklahoma City Thunder
# 7    Oklahoma City Thunder
# 8          Detroit Pistons
# 9              LA Clippers
# 10   Golden State Warriors
# 11      Philadelphia 76ers
# 12               Utah Jazz
# 13         Detroit Pistons
# 14        Sacramento Kings
# 15     Cleveland Cavaliers
# 16         Houston Rockets
# 17        Sacramento Kings
# 18       Memphis Grizzlies
# 19             LA Clippers
# 20  Portland Trail Blazers
# 21          Boston Celtics
# 22     Cleveland Cavaliers
# 23           Atlanta Hawks
# 24           Orlando Magic

# %%
teams_df = pd.json_normalize(teams_api, record_path =['data'])
teams_df
# Out:
#     id abbreviation           city conference   division  \
# 0    1          ATL        Atlanta       East  Southeast
# 1    2          BOS         Boston       East   Atlantic
# 2    3          BKN       Brooklyn       East   Atlantic
# 3    4          CHA      Charlotte       East  Southeast
# 4    5          CHI        Chicago       East    Central
# 5    6          CLE      Cleveland       East    Central
# 6    7          DAL         Dallas       West  Southwest
# 7    8          DEN         Denver       West  Northwest
# 8    9          DET        Detroit       East    Central
# 9   10          GSW   Golden State       West    Pacific
# 10  11          HOU        Houston       West  Southwest
# 11  12          IND        Indiana       East    Central
# 12  13          LAC             LA       West    Pacific
# 13  14          LAL    Los Angeles       West    Pacific
# 14  15          MEM        Memphis       West  Southwest
# 15  16          MIA          Miami       East  Southeast
# 16  17          MIL      Milwaukee       East    Central
# 17  18          MIN      Minnesota       West  Northwest
# 18  19          NOP    New Orleans       West  Southwest
# 19  20          NYK       New York       East   Atlantic
# 20  21          OKC  Oklahoma City       West  Northwest
# 21  22          ORL        Orlando       East  Southeast
# 22  23          PHI   Philadelphia       East   Atlantic
# 23  24          PHX        Phoenix       West    Pacific
# 24  25          POR       Portland       West  Northwest
# 25  26          SAC     Sacramento       West    Pacific
# 26  27          SAS    San Antonio       West  Southwest
# 27  28          TOR        Toronto       East   Atlantic
# 28  29          UTA           Utah       West  Northwest
# 29  30          WAS     Washington       East  Southeast
#
#                  full_name           name
# 0            Atlanta Hawks          Hawks
# 1           Boston Celtics        Celtics
# 2            Brooklyn Nets           Nets
# 3        Charlotte Hornets        Hornets
# 4            Chicago Bulls          Bulls
# 5      Cleveland Cavaliers      Cavaliers
# 6         Dallas Mavericks      Mavericks
# 7           Denver Nuggets        Nuggets
# 8          Detroit Pistons        Pistons
# 9    Golden State Warriors       Warriors
# 10         Houston Rockets        Rockets
# 11          Indiana Pacers         Pacers
# 12             LA Clippers       Clippers
# 13      Los Angeles Lakers         Lakers
# 14       Memphis Grizzlies      Grizzlies
# 15              Miami Heat           Heat
# 16         Milwaukee Bucks          Bucks
# 17  Minnesota Timberwolves   Timberwolves
# 18    New Orleans Pelicans       Pelicans
# 19         New York Knicks         Knicks
# 20   Oklahoma City Thunder        Thunder
# 21           Orlando Magic          Magic
# 22      Philadelphia 76ers          76ers
# 23            Phoenix Suns           Suns
# 24  Portland Trail Blazers  Trail Blazers
# 25        Sacramento Kings          Kings
# 26       San Antonio Spurs          Spurs
# 27         Toronto Raptors        Raptors
# 28               Utah Jazz           Jazz
# 29      Washington Wizards        Wizards

# %%
teams_df.drop(['abbreviation','city','conference','division','name'], axis=1, inplace=True)

# %%
teams_df
# Out:
#     id               full_name
# 0    1           Atlanta Hawks
# 1    2          Boston Celtics
# 2    3           Brooklyn Nets
# 3    4       Charlotte Hornets
# 4    5           Chicago Bulls
# 5    6     Cleveland Cavaliers
# 6    7        Dallas Mavericks
# 7    8          Denver Nuggets
# 8    9         Detroit Pistons
# 9   10   Golden State Warriors
# 10  11         Houston Rockets
# 11  12          Indiana Pacers
# 12  13             LA Clippers
# 13  14      Los Angeles Lakers
# 14  15       Memphis Grizzlies
# 15  16              Miami Heat
# 16  17         Milwaukee Bucks
# 17  18  Minnesota Timberwolves
# 18  19    New Orleans Pelicans
# 19  20         New York Knicks
# 20  21   Oklahoma City Thunder
# 21  22           Orlando Magic
# 22  23      Philadelphia 76ers
# 23  24            Phoenix Suns
# 24  25  Portland Trail Blazers
# 25  26        Sacramento Kings
# 26  27       San Antonio Spurs
# 27  28         Toronto Raptors
# 28  29               Utah Jazz
# 29  30      Washington Wizards

# %%
teams_final_df = teams_df.rename(columns={'id': 'team_id', 'full_name':'team_full_name'})
teams_final_df
# Out:
#     team_id          team_full_name
# 0         1           Atlanta Hawks
# 1         2          Boston Celtics
# 2         3           Brooklyn Nets
# 3         4       Charlotte Hornets
# 4         5           Chicago Bulls
# 5         6     Cleveland Cavaliers
# 6         7        Dallas Mavericks
# 7         8          Denver Nuggets
# 8         9         Detroit Pistons
# 9        10   Golden State Warriors
# 10       11         Houston Rockets
# 11       12          Indiana Pacers
# 12       13             LA Clippers
# 13       14      Los Angeles Lakers
# 14       15       Memphis Grizzlies
# 15       16              Miami Heat
# 16       17         Milwaukee Bucks
# 17       18  Minnesota Timberwolves
# 18       19    New Orleans Pelicans
# 19       20         New York Knicks
# 20       21   Oklahoma City Thunder
# 21       22           Orlando Magic
# 22       23      Philadelphia 76ers
# 23       24            Phoenix Suns
# 24       25  Portland Trail Blazers
# 25       26        Sacramento Kings
# 26       27       San Antonio Spurs
# 27       28         Toronto Raptors
# 28       29               Utah Jazz
# 29       30      Washington Wizards

# %%
games_df = pd.json_normalize(games_api, record_path =['data'])
games_df
# Out:
#        id                      date  home_team_score  period  postseason  \
# 0   47179  2019-01-30T00:00:00.000Z              126       4       False
# 1   48751  2019-02-09T00:00:00.000Z              112       4       False
# 2   48739  2019-02-08T00:00:00.000Z              117       4       False
# 3   48740  2019-02-08T00:00:00.000Z              119       4       False
# 4   48746  2019-02-08T00:00:00.000Z              102       4       False
# 5   48762  2019-02-11T00:00:00.000Z              121       4       False
# 6   48745  2019-02-08T00:00:00.000Z              122       4       False
# 7   48748  2019-02-09T00:00:00.000Z              105       4       False
# 8   48749  2019-02-09T00:00:00.000Z              120       4       False
# 9   48747  2019-02-09T00:00:00.000Z              125       4       False
# 10  48752  2019-02-09T00:00:00.000Z              125       4       False
# 11  48756  2019-02-10T00:00:00.000Z              102       4       False
# 12  48760  2019-02-10T00:00:00.000Z              143       4       False
# 13  48757  2019-02-10T00:00:00.000Z              117       4       False
# 14  48755  2019-02-09T00:00:00.000Z               83       4       False
# 15  48754  2019-02-09T00:00:00.000Z              112       4       False
# 16  48759  2019-02-10T00:00:00.000Z              120       4       False
# 17  48758  2019-02-10T00:00:00.000Z              108       4       False
# 18  48766  2019-02-11T00:00:00.000Z              120       4       False
# 19  48764  2019-02-11T00:00:00.000Z              127       4       False
# 20  48770  2019-02-12T00:00:00.000Z              117       4       False
# 21  48763  2019-02-11T00:00:00.000Z               99       4       False
# 22  48765  2019-02-11T00:00:00.000Z               99       4       False
# 23  48774  2019-02-12T00:00:00.000Z              115       4       False
# 24  48772  2019-02-12T00:00:00.000Z              107       4       False
#
#     season status   time  visitor_team_score  home_team.id  ...  \
# 0     2018  Final                         94             2  ...
# 1     2018  Final                        123             2  ...
# 2     2018  Final                        110            23  ...
# 3     2018  Final                        106            30  ...
# 4     2018  Final                         96            26  ...
# 5     2018  Final                        112             9  ...
# 6     2018  Final                        117            19  ...
# 7     2018  Final                         90            12  ...
# 8     2018  Final                        129             1  ...
# 9     2018  Final                        105            29  ...
# 10    2018  Final                        134             5  ...
# 11    2018  Final                        101             7  ...
# 12    2018  Final                        120            23  ...
# 13    2018  Final                        104            26  ...
# 14    2018  Final                        103            17  ...
# 15    2018  Final                        117            11  ...
# 16    2018  Final                        118            10  ...
# 17    2018  Final                        124             1  ...
# 18    2018  Final                        104            11  ...
# 19    2018  Final                        125            28  ...
# 20    2018  Final                        113             1  ...
# 21    2018  Final                         90            12  ...
# 22    2018  Final                        112             5  ...
# 23    2018  Final                        108            10  ...
# 24    2018  Final                        108            15  ...
#
#    home_team.division    home_team.full_name home_team.name visitor_team.id  \
# 0            Atlantic         Boston Celtics        Celtics               4
# 1            Atlantic         Boston Celtics        Celtics              13
# 2            Atlantic     Philadelphia 76ers          76ers               8
# 3           Southeast     Washington Wizards        Wizards               6
# 4             Pacific       Sacramento Kings          Kings              16
# 5             Central        Detroit Pistons        Pistons              30
# 6           Southwest   New Orleans Pelicans       Pelicans              18
# 7             Central         Indiana Pacers         Pacers               6
# 8           Southeast          Atlanta Hawks          Hawks               4
# 9           Northwest              Utah Jazz           Jazz              27
# 10            Central          Chicago Bulls          Bulls              30
# 11          Southwest       Dallas Mavericks      Mavericks              25
# 12           Atlantic     Philadelphia 76ers          76ers              14
# 13            Pacific       Sacramento Kings          Kings              24
# 14            Central        Milwaukee Bucks          Bucks              22
# 15          Southwest        Houston Rockets        Rockets              21
# 16            Pacific  Golden State Warriors       Warriors              16
# 17          Southeast          Atlanta Hawks          Hawks              22
# 18          Southwest        Houston Rockets        Rockets               7
# 19           Atlantic        Toronto Raptors        Raptors               3
# 20          Southeast          Atlanta Hawks          Hawks              14
# 21            Central         Indiana Pacers         Pacers               4
# 22            Central          Chicago Bulls          Bulls              17
# 23            Pacific  Golden State Warriors       Warriors              29
# 24          Southwest      Memphis Grizzlies      Grizzlies              27
#
#    visitor_team.abbreviation visitor_team.city  visitor_team.conference  \
# 0                        CHA         Charlotte                     East
# 1                        LAC                LA                     West
# 2                        DEN            Denver                     West
# 3                        CLE         Cleveland                     East
# 4                        MIA             Miami                     East
# 5                        WAS        Washington                     East
# 6                        MIN         Minnesota                     West
# 7                        CLE         Cleveland                     East
# 8                        CHA         Charlotte                     East
# 9                        SAS       San Antonio                     West
# 10                       WAS        Washington                     East
# 11                       POR          Portland                     West
# 12                       LAL       Los Angeles                     West
# 13                       PHX           Phoenix                     West
# 14                       ORL           Orlando                     East
# 15                       OKC     Oklahoma City                     West
# 16                       MIA             Miami                     East
# 17                       ORL           Orlando                     East
# 18                       DAL            Dallas                     West
# 19                       BKN          Brooklyn                     East
# 20                       LAL       Los Angeles                     West
# 21                       CHA         Charlotte                     East
# 22                       MIL         Milwaukee                     East
# 23                       UTA              Utah                     West
# 24                       SAS       San Antonio                     West
#
#    visitor_team.division  visitor_team.full_name visitor_team.name
# 0              Southeast       Charlotte Hornets           Hornets
# 1                Pacific             LA Clippers          Clippers
# 2              Northwest          Denver Nuggets           Nuggets
# 3                Central     Cleveland Cavaliers         Cavaliers
# 4              Southeast              Miami Heat              Heat
# 5              Southeast      Washington Wizards           Wizards
# 6              Northwest  Minnesota Timberwolves      Timberwolves
# 7                Central     Cleveland Cavaliers         Cavaliers
# 8              Southeast       Charlotte Hornets           Hornets
# 9              Southwest       San Antonio Spurs             Spurs
# 10             Southeast      Washington Wizards           Wizards
# 11             Northwest  Portland Trail Blazers     Trail Blazers
# 12               Pacific      Los Angeles Lakers            Lakers
# 13               Pacific            Phoenix Suns              Suns
# 14             Southeast           Orlando Magic             Magic
# 15             Northwest   Oklahoma City Thunder           Thunder
# 16             Southeast              Miami Heat              Heat
# 17             Southeast           Orlando Magic             Magic
# 18             Southwest        Dallas Mavericks         Mavericks
# 19              Atlantic           Brooklyn Nets              Nets
# 20               Pacific      Los Angeles Lakers            Lakers
# 21             Southeast       Charlotte Hornets           Hornets
# 22               Central         Milwaukee Bucks             Bucks
# 23             Northwest               Utah Jazz              Jazz
# 24             Southwest       San Antonio Spurs             Spurs
#
# [25 rows x 23 columns]

# %%
games_df.drop(['visitor_team.abbreviation','visitor_team.city','home_team.division','visitor_team.conference', 'visitor_team.name','home_team.name','visitor_team.division'], axis=1, inplace=True)
games_df
# Out:
#        id                      date  home_team_score  period  postseason  \
# 0   47179  2019-01-30T00:00:00.000Z              126       4       False
# 1   48751  2019-02-09T00:00:00.000Z              112       4       False
# 2   48739  2019-02-08T00:00:00.000Z              117       4       False
# 3   48740  2019-02-08T00:00:00.000Z              119       4       False
# 4   48746  2019-02-08T00:00:00.000Z              102       4       False
# 5   48762  2019-02-11T00:00:00.000Z              121       4       False
# 6   48745  2019-02-08T00:00:00.000Z              122       4       False
# 7   48748  2019-02-09T00:00:00.000Z              105       4       False
# 8   48749  2019-02-09T00:00:00.000Z              120       4       False
# 9   48747  2019-02-09T00:00:00.000Z              125       4       False
# 10  48752  2019-02-09T00:00:00.000Z              125       4       False
# 11  48756  2019-02-10T00:00:00.000Z              102       4       False
# 12  48760  2019-02-10T00:00:00.000Z              143       4       False
# 13  48757  2019-02-10T00:00:00.000Z              117       4       False
# 14  48755  2019-02-09T00:00:00.000Z               83       4       False
# 15  48754  2019-02-09T00:00:00.000Z              112       4       False
# 16  48759  2019-02-10T00:00:00.000Z              120       4       False
# 17  48758  2019-02-10T00:00:00.000Z              108       4       False
# 18  48766  2019-02-11T00:00:00.000Z              120       4       False
# 19  48764  2019-02-11T00:00:00.000Z              127       4       False
# 20  48770  2019-02-12T00:00:00.000Z              117       4       False
# 21  48763  2019-02-11T00:00:00.000Z               99       4       False
# 22  48765  2019-02-11T00:00:00.000Z               99       4       False
# 23  48774  2019-02-12T00:00:00.000Z              115       4       False
# 24  48772  2019-02-12T00:00:00.000Z              107       4       False
#
#     season status   time  visitor_team_score  home_team.id  \
# 0     2018  Final                         94             2
# 1     2018  Final                        123             2
# 2     2018  Final                        110            23
# 3     2018  Final                        106            30
# 4     2018  Final                         96            26
# 5     2018  Final                        112             9
# 6     2018  Final                        117            19
# 7     2018  Final                         90            12
# 8     2018  Final                        129             1
# 9     2018  Final                        105            29
# 10    2018  Final                        134             5
# 11    2018  Final                        101             7
# 12    2018  Final                        120            23
# 13    2018  Final                        104            26
# 14    2018  Final                        103            17
# 15    2018  Final                        117            11
# 16    2018  Final                        118            10
# 17    2018  Final                        124             1
# 18    2018  Final                        104            11
# 19    2018  Final                        125            28
# 20    2018  Final                        113             1
# 21    2018  Final                         90            12
# 22    2018  Final                        112             5
# 23    2018  Final                        108            10
# 24    2018  Final                        108            15
#
#    home_team.abbreviation home_team.city home_team.conference  \
# 0                     BOS         Boston                 East
# 1                     BOS         Boston                 East
# 2                     PHI   Philadelphia                 East
# 3                     WAS     Washington                 East
# 4                     SAC     Sacramento                 West
# 5                     DET        Detroit                 East
# 6                     NOP    New Orleans                 West
# 7                     IND        Indiana                 East
# 8                     ATL        Atlanta                 East
# 9                     UTA           Utah                 West
# 10                    CHI        Chicago                 East
# 11                    DAL         Dallas                 West
# 12                    PHI   Philadelphia                 East
# 13                    SAC     Sacramento                 West
# 14                    MIL      Milwaukee                 East
# 15                    HOU        Houston                 West
# 16                    GSW   Golden State                 West
# 17                    ATL        Atlanta                 East
# 18                    HOU        Houston                 West
# 19                    TOR        Toronto                 East
# 20                    ATL        Atlanta                 East
# 21                    IND        Indiana                 East
# 22                    CHI        Chicago                 East
# 23                    GSW   Golden State                 West
# 24                    MEM        Memphis                 West
#
#       home_team.full_name  visitor_team.id  visitor_team.full_name
# 0          Boston Celtics                4       Charlotte Hornets
# 1          Boston Celtics               13             LA Clippers
# 2      Philadelphia 76ers                8          Denver Nuggets
# 3      Washington Wizards                6     Cleveland Cavaliers
# 4        Sacramento Kings               16              Miami Heat
# 5         Detroit Pistons               30      Washington Wizards
# 6    New Orleans Pelicans               18  Minnesota Timberwolves
# 7          Indiana Pacers                6     Cleveland Cavaliers
# 8           Atlanta Hawks                4       Charlotte Hornets
# 9               Utah Jazz               27       San Antonio Spurs
# 10          Chicago Bulls               30      Washington Wizards
# 11       Dallas Mavericks               25  Portland Trail Blazers
# 12     Philadelphia 76ers               14      Los Angeles Lakers
# 13       Sacramento Kings               24            Phoenix Suns
# 14        Milwaukee Bucks               22           Orlando Magic
# 15        Houston Rockets               21   Oklahoma City Thunder
# 16  Golden State Warriors               16              Miami Heat
# 17          Atlanta Hawks               22           Orlando Magic
# 18        Houston Rockets                7        Dallas Mavericks
# 19        Toronto Raptors                3           Brooklyn Nets
# 20          Atlanta Hawks               14      Los Angeles Lakers
# 21         Indiana Pacers                4       Charlotte Hornets
# 22          Chicago Bulls               17         Milwaukee Bucks
# 23  Golden State Warriors               29               Utah Jazz
# 24      Memphis Grizzlies               27       San Antonio Spurs

# %%
games_df.drop(['home_team.abbreviation','home_team.city','home_team.conference'], axis=1, inplace=True)
games_df
# Out:
#        id                      date  home_team_score  period  postseason  \
# 0   47179  2019-01-30T00:00:00.000Z              126       4       False
# 1   48751  2019-02-09T00:00:00.000Z              112       4       False
# 2   48739  2019-02-08T00:00:00.000Z              117       4       False
# 3   48740  2019-02-08T00:00:00.000Z              119       4       False
# 4   48746  2019-02-08T00:00:00.000Z              102       4       False
# 5   48762  2019-02-11T00:00:00.000Z              121       4       False
# 6   48745  2019-02-08T00:00:00.000Z              122       4       False
# 7   48748  2019-02-09T00:00:00.000Z              105       4       False
# 8   48749  2019-02-09T00:00:00.000Z              120       4       False
# 9   48747  2019-02-09T00:00:00.000Z              125       4       False
# 10  48752  2019-02-09T00:00:00.000Z              125       4       False
# 11  48756  2019-02-10T00:00:00.000Z              102       4       False
# 12  48760  2019-02-10T00:00:00.000Z              143       4       False
# 13  48757  2019-02-10T00:00:00.000Z              117       4       False
# 14  48755  2019-02-09T00:00:00.000Z               83       4       False
# 15  48754  2019-02-09T00:00:00.000Z              112       4       False
# 16  48759  2019-02-10T00:00:00.000Z              120       4       False
# 17  48758  2019-02-10T00:00:00.000Z              108       4       False
# 18  48766  2019-02-11T00:00:00.000Z              120       4       False
# 19  48764  2019-02-11T00:00:00.000Z              127       4       False
# 20  48770  2019-02-12T00:00:00.000Z              117       4       False
# 21  48763  2019-02-11T00:00:00.000Z               99       4       False
# 22  48765  2019-02-11T00:00:00.000Z               99       4       False
# 23  48774  2019-02-12T00:00:00.000Z              115       4       False
# 24  48772  2019-02-12T00:00:00.000Z              107       4       False
#
#     season status   time  visitor_team_score  home_team.id  \
# 0     2018  Final                         94             2
# 1     2018  Final                        123             2
# 2     2018  Final                        110            23
# 3     2018  Final                        106            30
# 4     2018  Final                         96            26
# 5     2018  Final                        112             9
# 6     2018  Final                        117            19
# 7     2018  Final                         90            12
# 8     2018  Final                        129             1
# 9     2018  Final                        105            29
# 10    2018  Final                        134             5
# 11    2018  Final                        101             7
# 12    2018  Final                        120            23
# 13    2018  Final                        104            26
# 14    2018  Final                        103            17
# 15    2018  Final                        117            11
# 16    2018  Final                        118            10
# 17    2018  Final                        124             1
# 18    2018  Final                        104            11
# 19    2018  Final                        125            28
# 20    2018  Final                        113             1
# 21    2018  Final                         90            12
# 22    2018  Final                        112             5
# 23    2018  Final                        108            10
# 24    2018  Final                        108            15
#
#       home_team.full_name  visitor_team.id  visitor_team.full_name
# 0          Boston Celtics                4       Charlotte Hornets
# 1          Boston Celtics               13             LA Clippers
# 2      Philadelphia 76ers                8          Denver Nuggets
# 3      Washington Wizards                6     Cleveland Cavaliers
# 4        Sacramento Kings               16              Miami Heat
# 5         Detroit Pistons               30      Washington Wizards
# 6    New Orleans Pelicans               18  Minnesota Timberwolves
# 7          Indiana Pacers                6     Cleveland Cavaliers
# 8           Atlanta Hawks                4       Charlotte Hornets
# 9               Utah Jazz               27       San Antonio Spurs
# 10          Chicago Bulls               30      Washington Wizards
# 11       Dallas Mavericks               25  Portland Trail Blazers
# 12     Philadelphia 76ers               14      Los Angeles Lakers
# 13       Sacramento Kings               24            Phoenix Suns
# 14        Milwaukee Bucks               22           Orlando Magic
# 15        Houston Rockets               21   Oklahoma City Thunder
# 16  Golden State Warriors               16              Miami Heat
# 17          Atlanta Hawks               22           Orlando Magic
# 18        Houston Rockets                7        Dallas Mavericks
# 19        Toronto Raptors                3           Brooklyn Nets
# 20          Atlanta Hawks               14      Los Angeles Lakers
# 21         Indiana Pacers                4       Charlotte Hornets
# 22          Chicago Bulls               17         Milwaukee Bucks
# 23  Golden State Warriors               29               Utah Jazz
# 24      Memphis Grizzlies               27       San Antonio Spurs

# %%
games_final_df = games_df.rename(columns={'id' : 'game_id','home_team.id : home_team_id',})
games_final_df
# 'id:game_id','home_team.id:home_team_id','home_team.full_name:home_team_full_name','visitor_team.id:visitor_team_id','visitor_team.full_name:visitor_team-full_name'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-716bedc89766> in <module>
# ----> 1 games_final_df = games_df.rename(columns={'id : game_id','home_team.id : home_team_id'})
#       2 games_final_df
#       3 # 'id:game_id','home_team.id:home_team_id','home_team.full_name:home_team_full_name','visitor_team.id:visitor_team_id','visitor_team.full_name:visitor_team-full_name'
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     310         @wraps(func)
#     311         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 312             return func(*args, **kwargs)
#     313
#     314         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4439         4  3  6
#    4440         """
# -> 4441         return super().rename(
#    4442             mapper=mapper,
#    4443             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1055                     raise KeyError(f"{missing_labels} not found in axis")
#    1056
# -> 1057             new_index = ax._transform_index(f, level)
#    1058             result._set_axis_nocheck(new_index, axis=axis_no, inplace=True)
#    1059             result._clear_item_cache()
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _transform_index(self, func, level)
#    5136             return type(self).from_tuples(items, names=self.names)
#    5137         else:
# -> 5138             items = [func(x) for x in self]
#    5139             return Index(items, name=self.name, tupleize_cols=False)
#    5140
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in <listcomp>(.0)
#    5136             return type(self).from_tuples(items, names=self.names)
#    5137         else:
# -> 5138             items = [func(x) for x in self]
#    5139             return Index(items, name=self.name, tupleize_cols=False)
#    5140
#
# TypeError: 'set' object is not callable

# %%
stats_df = pd.json_normalize(stats_api, record_path =['data'])
stats_df
stats_df_head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-24bc389fa236> in <module>
# ----> 1 stats_df = pd.json_normalize(stats_api, record_path =['data'])
#       2 stats_df
#       3 stats_df_head()
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     334                 records.extend(recs)
#     335
# --> 336     _recursive_extract(data, record_path, {}, level=0)
#     337
#     338     result = DataFrame(records)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     307         else:
#     308             for obj in data:
# --> 309                 recs = _pull_records(obj, path[0])
#     310                 recs = [
#     311                     nested_to_record(r, sep=sep, max_level=max_level)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _pull_records(js, spec)
#     246         if has non iterable value.
#     247         """
# --> 248         result = _pull_field(js, spec)
#     249
#     250         # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _pull_field(js, spec)
#     237                 result = result[field]
#     238         else:
# --> 239             result = result[spec]
#     240         return result
#     241
#
# TypeError: string indices must be integers

# %%
# conn = sqlite3.connect('Basketball_stats.db')
# player_final_df2.to_sql('players', conn, if_exists='replace', index=False)
# teams_final_df.to_sql('teams', conn, if_exists='replace', index=False)
# # cnx = sqlite3.connect(':memory:')
# # player_final_df2.to_sql(name='players', con=cnx)
# # p2 = pd.read_sql('select * from players', cnx)
# # p2

# %%
# engine = create_engine("sqlite:///Basketball_stats.sqlite")
# pd.read_sql('select * from players', conn)
# Out:
#     player_id first_name   last_name positions  team_id  \
# 0          14        Ike    Anigbogu         C       12
# 1          25        Ron       Baker         G       20
# 2          47     Jabari        Bird         G        2
# 3          67    MarShon      Brooks         G       15
# 4          71    Lorenzo       Brown         G       28
# 5          90       Omri      Casspi         F       15
# 6           1       Alex     Abrines         G       21
# 7         119      Tyler       Davis         C       21
# 8         149     Keenan       Evans         G        9
# 9         179     Marcin      Gortat         C       13
# 10       1593     Andrew       Bogut         F       10
# 11        241       Amir     Johnson       C-F       23
# 12        392    Malachi  Richardson         G       29
# 13        281       Zach      Lofton         G        9
# 14        263      Kosta      Koufos         C       26
# 15        382      Billy     Preston         F        6
# 16        384       Zhou          Qi       F-C       11
# 17        388       Zach    Randolph         F       26
# 18        430         DJ    Stephens       G-F       15
# 19        437      Milos    Teodosic         G       13
# 20        448       Gary   Trent Jr.         G       25
# 21        494    Michael       Smith                  2
# 22        495       John      Morton                  6
# 23        496     Howard      Wright                  1
# 24        497    Michael      Ansley                 22
#
#             team_full_name
# 0           Indiana Pacers
# 1          New York Knicks
# 2           Boston Celtics
# 3        Memphis Grizzlies
# 4          Toronto Raptors
# 5        Memphis Grizzlies
# 6    Oklahoma City Thunder
# 7    Oklahoma City Thunder
# 8          Detroit Pistons
# 9              LA Clippers
# 10   Golden State Warriors
# 11      Philadelphia 76ers
# 12               Utah Jazz
# 13         Detroit Pistons
# 14        Sacramento Kings
# 15     Cleveland Cavaliers
# 16         Houston Rockets
# 17        Sacramento Kings
# 18       Memphis Grizzlies
# 19             LA Clippers
# 20  Portland Trail Blazers
# 21          Boston Celtics
# 22     Cleveland Cavaliers
# 23           Atlanta Hawks
# 24           Orlando Magic

# %%
# # reflect an existing database into a new model
# Base = automap_base()
# # reflect the tables
# Base.prepare(engine, reflect=True)
# Base.classes.keys()
# # # Save reference to the table
# # Players = Base.classes.players
# # Teams = Base.classes.teams
# Out:
# []

# %%
# inspector = inspect(engine)
# table_names = inspector.get_table_names()

# %%
connection_string = "postgres:postgres@localhost:5432/Basketball_stats"
engine = create_engine(f'postgresql://{connection_string}')

# %%
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['players', 'teams']

# %%
player_final_df2.to_sql(name='players', con=engine, if_exists='replace', index=True)

# %%
teams_final_df.to_sql(name='teams', con=engine, if_exists='replace', index=True)

# %%
Base.classes.players()

# %%
pd.read_sql('select * from players', engine)
# Out:
#     index  player_id first_name   last_name positions  team_id  \
# 0       0         14        Ike    Anigbogu         C       12
# 1       1         25        Ron       Baker         G       20
# 2       2         47     Jabari        Bird         G        2
# 3       3         67    MarShon      Brooks         G       15
# 4       4         71    Lorenzo       Brown         G       28
# 5       5         90       Omri      Casspi         F       15
# 6       6          1       Alex     Abrines         G       21
# 7       7        119      Tyler       Davis         C       21
# 8       8        149     Keenan       Evans         G        9
# 9       9        179     Marcin      Gortat         C       13
# 10     10       1593     Andrew       Bogut         F       10
# 11     11        241       Amir     Johnson       C-F       23
# 12     12        392    Malachi  Richardson         G       29
# 13     13        281       Zach      Lofton         G        9
# 14     14        263      Kosta      Koufos         C       26
# 15     15        382      Billy     Preston         F        6
# 16     16        384       Zhou          Qi       F-C       11
# 17     17        388       Zach    Randolph         F       26
# 18     18        430         DJ    Stephens       G-F       15
# 19     19        437      Milos    Teodosic         G       13
# 20     20        448       Gary   Trent Jr.         G       25
# 21     21        494    Michael       Smith                  2
# 22     22        495       John      Morton                  6
# 23     23        496     Howard      Wright                  1
# 24     24        497    Michael      Ansley                 22
#
#             team_full_name
# 0           Indiana Pacers
# 1          New York Knicks
# 2           Boston Celtics
# 3        Memphis Grizzlies
# 4          Toronto Raptors
# 5        Memphis Grizzlies
# 6    Oklahoma City Thunder
# 7    Oklahoma City Thunder
# 8          Detroit Pistons
# 9              LA Clippers
# 10   Golden State Warriors
# 11      Philadelphia 76ers
# 12               Utah Jazz
# 13         Detroit Pistons
# 14        Sacramento Kings
# 15     Cleveland Cavaliers
# 16         Houston Rockets
# 17        Sacramento Kings
# 18       Memphis Grizzlies
# 19             LA Clippers
# 20  Portland Trail Blazers
# 21          Boston Celtics
# 22     Cleveland Cavaliers
# 23           Atlanta Hawks
# 24           Orlando Magic
